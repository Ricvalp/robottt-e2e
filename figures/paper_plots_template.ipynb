# %% [markdown]
# # Paper Plots Template
#
# Set `RAW_DATA_PATH` below to one of the `.pt` files saved under an eval run's `raw_data/` directory.

# %%
from pathlib import Path
import sys

sys.path.append("..")

RAW_DATA_PATH = Path("")
RAW_DATA_PATH
# Out:
# PosixPath('.')

# %%
from diffusion.plotting import *
